# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install dominate
# !pip install omegaconf

# %% [markdown]
# Interface UO-SAM

# %%
import os, sys
sys.path.append('/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN')

# %%
from inference import main

# %%
# prompt: refaça a classe Args com o init

class Args:
  def __init__(self, configmodel, path_image, path_list, path_checkpoint, path_save, save=True, split='test', base='GTA5', model='CCT', multiscale=False):
    self.configmodel = configmodel
    self.path_image = path_image
    self.path_list = path_list
    self.path_checkpoint = path_checkpoint
    self.path_save = path_save
    self.save = save
    self.split = split
    self.base = base
    self.model = model
    self.multiscale = multiscale

# %%
# prompt: inicialize a classe args

args = Args(configmodel='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/CCT/configs/config.json',
            path_image='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/CityScapeData',
            path_list='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/CityScapeData/city_list',
            path_checkpoint='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/CCT/modelsaved/CCT_CityScape_GTA5_2/best_model.pth',
            path_save='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/UOSAM',
            save=True,
            split='test',
            base='Cityscapes',
            model='CCT',
            multiscale=False)

# %%
main(args.configmodel,args.path_image, args.path_list, args.path_checkpoint, args.path_save, args.save, args.split, args.base, args.model, args.multiscale)
# Out:
# /content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/UOSAM/CCT/Cityscapes/test/mask/
# ...

# %%
args = Args(configmodel='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/CCT/configs/config.json',
            path_image='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/GTA5Dataset',
            path_list='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/GTA5Dataset/gta5_list',
            path_checkpoint='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/CCT/checkpoint/modelCCT_state_dict.pth',
            path_save='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/UOSAM',
            save=True,
            split='test',
            base='GTA5',
            model='CCT',
            multiscale=False)

# %%
main(args.configmodel,args.path_image, args.path_list, args.path_checkpoint, args.path_save, args.save, args.split, args.base, args.model, args.multiscale)
# Out:
# /content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/inference.py:189: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(path_checkpoint)
# ...

# %%
args = Args(configmodel='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/CCT/configs/config.json',
            path_image='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/CityScapesBrazil',
            path_list='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/CityScapesBrazil/brazil_list',
            path_checkpoint='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/CCT/checkpoint/modelCCT_state_dict.pth',
            path_save='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/UOSAM',
            save=True,
            split='test',
            base='Brazil',
            model='CCT',
            multiscale=False)

# %%
main(args.configmodel,args.path_image, args.path_list, args.path_checkpoint, args.path_save, args.save, args.split, args.base, args.model, args.multiscale)

# %%
args = Args(configmodel='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/CCT/configs/config.json',
            path_image='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/CityScapeData',
            path_list='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/CityScapeData/city_list',
            path_checkpoint='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/CCT/checkpoint/modelCCT_state_dict.pth',
            path_save='/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/UOSAM',
            save=True,
            split='test',
            base='Cityscapes',
            model='CCT',
            multiscale=True)

# %%
main(args.configmodel,args.path_image, args.path_list, args.path_checkpoint, args.path_save, args.save, args.split, args.base, args.model, args.multiscale)

# %% [markdown]
# # Verificando masks

# %%
from PIL import Image

# %%
image_path = '/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/GTA5Dataset/labels/00001.png'
imagegta = Image.open(image_path)


image_path = '/content/drive/MyDrive/TCC/LIGHT_ADAPTATION_DOMIAN/datasets/UOSAM/CCT/Cityscapes/test/mask/berlin_000000_000019_leftImg8bit.png'
image = Image.open(image_path)

# %%
image.size, image.mode

# %%
imagegta.size, imagegta.mode

# %%
import torch
from torchvision import transforms
import numpy as np

# %%
transform = transforms.ToTensor()

# Aplicar a transformação
image_tensor = transform(np.asarray(image, np.float32))
imagegta_tensor = transform(np.asarray(imagegta, np.float32))

# %%
torch.unique(image_tensor), torch.unique(imagegta_tensor)

# %%
import matplotlib.pyplot as plt

# Visualizar o target
plt.imshow(image)  # Remover a dimensão extra e usar mapa de cores em escala de cinza
plt.title("Target")
plt.show()

# %%
# Visualizar o target
plt.imshow(imagegta)  # Remover a dimensão extra e usar mapa de cores em escala de cinza
plt.title("Target")
plt.show()
